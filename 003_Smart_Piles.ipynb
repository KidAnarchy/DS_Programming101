# %%
"""
Created on Sun Jul 18 09:08:28 2021
@author: Nattawat Wattanawiput
Student ID: 640631031
Topic : Homework2 "Take X stick from the pile"
Lastest version make python computer player smarter than player, never lose. 26 Jul 2021
"""

N = int(input('How many sticks (N) in the pile:'))
print('There are', N, 'sticks in the pile.')
name = str(input('What is your name :'))
print('\nwho take the last stick lose!')

for T in range (N):

# Player 1 Somchai or Your name:

    print('\n')
    print(name ,',how many sticks you will take (1 or 2):')
    T = int(input())
    
    if T >=3:
        print('No you cannot take more than 2 sticks!')
        continue
    elif 1<= T <3:
        
        if T == 2:
            N = N - T  
            if N==0:
                print ('\nYou loss,',name,' End Game ')
                break
            elif N==1:
                if N == 1:
                    print ('\nI, smart computer, take the last stick.')
                    print (name, 'win (I, Smart computer, am sad T_T)')
                    break
            elif N < 0: 
                N = N + T
                print ('There is only 1 stick in pile, why will you take 2')
                continue
        elif T <= 1:
            N = N - T  
            if N<=0:
                print('\n',name,',take the last stick.')
                print('I, Smart computer, win!!!')
                break
            elif N==1:
                print ('\nI, smart computer, take the last stick.')
                print (name, 'win (I, smart computer, am sad T_T)')
                break
        else:
            print('There are not enough sticks to take.')
            continue
        print('There are', N, 'sticks in the pile.')  
        
    else:
        print('No you cannot take less than 1 stick!')
        continue
        
# Player 2 Python the smartest computer:
    
    for T2 in range (N):
        print('\nI, smart computer take :')
        
        if N > 3 and N % 3 == 0:
            N = N - 2
            print('2')
        elif N > 3 and N % 3 != 0:
            N = N - 1
            print('1') 
        elif N == 3:
            N = N - 2
            print('2')       
        elif N == 2:
            N = N - 1
            print('1') 
            
        else:
            print('Game Over')
            break
                
        print('There are', N, 'sticks in the pile.')
        break
        
    if N == 0:
        break  
# End Game
