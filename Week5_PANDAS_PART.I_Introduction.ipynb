# %% [markdown]
# # Week5_Pandas_introduction
#
# Import all libraries
#
# PANDAS SERIES OBJECT
#
# CONSTRUCTING SERIES OBJECTS
#
# PANDAS DATAFRAME OBJECT
#
# SERIES as DICTIONARY
#
# DATAFRAME as DICTIONARY
#
# Index Alignment Series

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # import all libraries

# %%
import numpy as np 
import pandas as pd
import scipy as sp
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# Check the version of your PANDAS

# %%
pd.__version__
# Out:
# '1.1.3'

# %% [markdown]
# ## **PANDAS SERIES OBJECT**

# %%
data = pd.Series([0.25,0.5,0.75,1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data[1]
# Out:
# 0.5

# %%
data[1:3]
# Out:
# 1    0.50
# 2    0.75
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = pd.Series([0.25,0.5,0.75,1.0],
                index = ['a','b','c','d'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = pd.Series([0.25,0.5,0.75,1.0],index = [2,5,3,7])
data
# Out:
# 2    0.25
# 5    0.50
# 3    0.75
# 7    1.00
# dtype: float64

# %% [markdown]
# what is `data[5]`

# %%
data[5]
# Out:
# 0.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
population_dict = {'California' : 38332521,
                   'Texas' : 26448193,
                  'New York' : 19651127,
                  'Florida' : 19552860,
                  'Illinois': 12882135}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population['California']
# Out:
# 38332521

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
population['California':'Florida']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# dtype: int64

# %% [markdown]
# ## **CONSTRUCTING SERIES OBJECTS**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.Series([2,4,6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
# pd.Series(data, index = index)
pd.Series(5,index=[100,200,300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.Series({2:'a', 1:'b', 3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
pd.Series({2:'a', 1:'b', 3:'c'}, index=[3,2])
# Out:
# 3    c
# 2    a
# dtype: object

# %% [markdown]
# ## **PANDAS DATAFRAME OBJECT**

# %%
area_dict = {'California':423967, 'Texas':695662, 'New':141297,
            'Florida':170312, 'Illinois':149995}
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New           141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({'population': population,
                      'area':area})
states
# Out:
#             population      area
# California  38332521.0  423967.0
# Florida     19552860.0  170312.0
# Illinois    12882135.0  149995.0
# New                NaN  141297.0
# New York    19651127.0       NaN
# Texas       26448193.0  695662.0

# %%
states.index
# Out:
# Index(['California', 'Florida', 'Illinois', 'New', 'New York', 'Texas'], dtype='object')

# %%
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %%
states['area']
# Out:
# California    423967.0
# Florida       170312.0
# Illinois      149995.0
# New           141297.0
# New York           NaN
# Texas         695662.0
# Name: area, dtype: float64

# %% [markdown]
# ## **CONSTRUCTING DATAFRAME OBJECT**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.DataFrame(population, columns=['population'])
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %%
pd.DataFrame(population, columns=['area'])
# Out:
#                 area
# California  38332521
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = [{'a':i, 'b':2*i} for i in range(3)]
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.DataFrame([{'a':1, 'b':2}, {'b':3, 'c':4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %% [markdown]
# **WHAT is `NAN`** ?
#
# ---

# %% [markdown]
# **ANSWER** = NaN stands for Not A Number and is one of the common ways to represent the missing value in the data. It is a special floating-point value and cannot be converted to any other type than float. NaN value is one of the major problems in Data Analysis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.DataFrame({'population': population,
                      'area':area})
# Out:
#             population      area
# California  38332521.0  423967.0
# Florida     19552860.0  170312.0
# Illinois    12882135.0  149995.0
# New                NaN  141297.0
# New York    19651127.0       NaN
# Texas       26448193.0  695662.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# From a two-dimensional Numpy Array

pd.DataFrame(np.random.rand(3,2),
            columns=['foo','bar'],
            index=['a','b','c'])
# Out:
#         foo       bar
# a  0.079313  0.441742
# b  0.669699  0.469590
# c  0.849729  0.086051

# %% [markdown]
# ## **SERIES as DICTIONARY**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
data = pd.Series([0.25,0.5,0.75,1.0],index=['a','b','c','d'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# 0.5

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]

# %%
data['e'] = 1.25
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %%
# slicing by explicit index
data['a':'c']
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
# slicing by implicit integer index
data[0:2]
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
# masking
data[(data>0.3) & (data<0.8)]
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
# fancy indexing
data[['a','e']]
# Out:
# a    0.25
# e    1.25
# dtype: float64

# %% [markdown]
# ## **DATAFRAME as DICTIONARY**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
area =pd.Series({'California':423967, 'Texas':695662,
                'New York':141297, 'Florida': 170312,
                'Illinois': 149995})
pop = pd.Series({'California':3833251, 'Texas':26448193,
                'New York':19651127, 'Florida': 19552860,
                'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967   3833251
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data.area is data['area']
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data['density'] = data['pop'] / data['area']
data
# Out:
#               area       pop     density
# California  423967   3833251    9.041390
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# In[24] [25] [32] [33] [34] [35]

# %%
data.values
# Out:
# array([[4.23967000e+05, 3.83325100e+06, 9.04139001e+00],
#        [6.95662000e+05, 2.64481930e+07, 3.80187404e+01],
#        [1.41297000e+05, 1.96511270e+07, 1.39076746e+02],
#        [1.70312000e+05, 1.95528600e+07, 1.14806121e+02],
#        [1.49995000e+05, 1.28821350e+07, 8.58837628e+01]])

# %%
data.T
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.833251e+06  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  9.041390e+00  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %%
# changed data in index1, column3

data.iloc[0,2] = 90
data
# Out:
#               area       pop     density
# California  423967   3833251   90.000000
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
data['Florida':'Illinois']
# Out:
#             area       pop     density
# Florida   170312  19552860  114.806121
# Illinois  149995  12882135   85.883763

# %%
data[1:3]
# Out:
#             area       pop     density
# Texas     695662  26448193   38.018740
# New York  141297  19651127  139.076746

# %%
data[data.density>100]
# Out:
#             area       pop     density
# New York  141297  19651127  139.076746
# Florida   170312  19552860  114.806121

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
area = pd.Series({'Alaska':1723337, 'Texas':695662,
                'California': 423967}, name ='area')
population = pd.Series({'California':38332521, 'Texas': 26448193,
                      'New York': 19651127}, name='population')

# %%
area
# Out:
# Alaska        1723337
# Texas          695662
# California     423967
# Name: area, dtype: int64

# %%
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Name: population, dtype: int64

# %%
population/area
# Out:
# Alaska              NaN
# California    90.413926
# New York            NaN
# Texas         38.018740
# dtype: float64

# %% [markdown]
# ## **MISSING VALUE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = pd.Series([2,4,6], index=[0,1,2])
B = pd.Series([1,3,5], index=[1,2,3])

# %%
A
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
B
# Out:
# 1    1
# 2    3
# 3    5
# dtype: int64

# %%
A + B
# Out:
# 0    NaN
# 1    5.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
A.add(B, fill_value = 0)
# Out:
# 0    2.0
# 1    5.0
# 2    9.0
# 3    5.0
# dtype: float64
